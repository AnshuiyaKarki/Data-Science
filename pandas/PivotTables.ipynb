# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    886     70   John  January      Q1
# 1  2023-01-02       B   West    525     62   Mary  January      Q1
# 2  2023-01-03       C  North    232     96    Bob  January      Q1
# 3  2023-01-04       D  South    155     67  Alice  January      Q1
# 4  2023-01-05       A   East    602     20   John  January      Q1
# 5  2023-01-06       B   West    708     19   Mary  January      Q1
# 6  2023-01-07       C  North    182     88    Bob  January      Q1
# 7  2023-01-08       D  South    302     37  Alice  January      Q1
# 8  2023-01-09       A   East    355     40   John  January      Q1
# 9  2023-01-10       B   West    721     94   Mary  January      Q1
# 10 2023-01-11       C  North    844     90    Bob  January      Q1
# 11 2023-01-12       D  South    808     43  Alice  January      Q1
# 12 2023-01-13       A   East    612     22   John  January      Q1
# ...

# %%
#pivot_table() is used to summarize data by grouping and aggregating.
df.pivot_table(values="Sales",index="Region",columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     612.0    NaN    NaN    NaN
# North      NaN    NaN  241.0    NaN
# South      NaN    NaN    NaN  302.0
# West       NaN  525.0    NaN    NaN

# %%
pivot2=df.pivot_table(values=["Sales","Units"], index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     646.0    NaN    NaN    NaN  32.4   NaN   NaN   NaN
# North      NaN    NaN  370.8    NaN   NaN   NaN  71.8   NaN
# South      NaN    NaN    NaN  461.2   NaN   NaN   NaN  55.2
# West       NaN  583.4    NaN    NaN   NaN  57.8   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
#pd.crosstab(row,col) is used to count the frequency of combinations between two (or more) categorical variables 
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
